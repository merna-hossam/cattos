# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np
from mpl_toolkits.mplot3d import axes3d

# %% [markdown]
# Alexandria University
# Collage of Data Science
# Data Science tools and software
#
# Assignment (1)

# %% [markdown]
# (1)Visualize a scatter plot that represent sepal length, sepal width,
# petal length and petal width in Iris Dataset

# %%
iris=pd.read_csv('IRIS.csv')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.sepal_length
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %% [markdown]
# (2)Visualize a 3D data with gray scale, colored and filled contour plot,
# X value = 50 samples from 0 to 5, Y value = 90 samples from 0 to 5,
# Z value represented by cos(X*Y*100) using meshgrid function to
# build 2D grids from 1D arrays and save your figures in .png images

# %%
plt.plot(iris.sepal_length, 'go')
plt.plot(iris.sepal_width,'bx')

# %%
plt.plot(iris.petal_length, 'co')
plt.plot(iris.petal_width,'rx')

# %%
x=np.linspace(0,5,50,endpoint='True')
y=np.linspace(0,5,90,endpoint='True')
fig=plt.figure(num='Figure One' )
plt.plot(x, 'co')
plt.plot(y,'rx')

# %%
X,Y = np.meshgrid(x,y)
Z = np.cos(X*Y*100)
fig = plt.figure(figsize=(6,6))
a = fig.add_subplot(111, projection='3d',facecolor='gray')
a.plot_surface(X, Y, Z)
plt.title('fig1')
plt.show()
fig.savefig('fig1.png')

# %% [markdown]
# (3)Perform Inner Join, Outer Join for the following tables

# %% [markdown]
# Table 1:

# %%
table=pd.DataFrame({'name':['Mary','Joseph'],'drink':['wine','beer']})

# %%
table
# Out:
#      name drink
# 0    Mary  wine
# 1  Joseph  beer

# %% [markdown]
# table 2:

# %%
table1=pd.DataFrame({'name':['peter','paul','Mary'],'food':['fish','beans','bread']})

# %%
table1
# Out:
#     name   food
# 0  peter   fish
# 1   paul  beans
# 2   Mary  bread

# %%
outer = pd.merge(table, table1, on='name', how='outer')

# %%
outer
# Out:
#      name drink   food
# 0    Mary  wine  bread
# 1  Joseph  beer    NaN
# 2   peter   NaN   fish
# 3    paul   NaN  beans

# %%
inner = pd.merge(table, table1, on='name', how='inner')

# %%
inner
# Out:
#    name drink   food
# 0  Mary  wine  bread
